# %% [markdown]
# ## Export google colab execution result into PDF file

# %% [markdown]
# Using nbconvert function with available for 2 methods; choose one as your favor

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd <STORE PATH>
# %cd /content/drive/MyDrive/Colab_Notebooks/TA/BDA/Assignment01

# %% [markdown]
# Method I: convert ipynb into HTML then save as PDF

# %% [markdown]
# After execution the command, the HTML file will be write to currently dir, then download that HTML file, open it and save as PDF respectively.

# %%
# !jupyter nbconvert --to html <PATH + FILENAME>
# !jupyter nbconvert --to html /content/drive/MyDrive/Colab_Notebooks/TA/BDA/Assignment01/Assignment1_StudentID.ipynb
